# %% [markdown]
# <a href="https://colab.research.google.com/github/Wishmi-Sasika/SLIIT-AI-ML-Stage-1/blob/main/AI_ML_Tensorflow_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Data

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/selva86/datasets/master/Ionosphere.csv"
df = pd.read_csv (url)
df.head()
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        V10  ...      V26      V27      V28      V29      V30      V31  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#        V32      V33      V34  Class
# 0 -0.54487  0.18641 -0.45300      1
# ...

# %% [markdown]
# # Identifying the dependant and independant variables

# %%
x = df.drop(['Class'], axis = 1)
y = df['Class']

# %%
# Dependant variable
print (y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 346    1
# 347    1
# 348    1
# 349    1
# 350    1
# Name: Class, Length: 351, dtype: int64

# %%
# Independant variable
print (x)
# Out:
#      V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 0     1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1     1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2     1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3     1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4     1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
# ..   ..  ..      ...      ...      ...      ...      ...      ...      ...
# 346   1   0  0.83508  0.08298  0.73739 -0.14706  0.84349 -0.05567  0.90441
# 347   1   0  0.95113  0.00419  0.95183 -0.02723  0.93438 -0.01920  0.94590
# 348   1   0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431  0.95584
# 349   1   0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646  0.85746
# 350   1   0  0.84710  0.13533  0.73638 -0.06151  0.87873  0.08260  0.88928
#
# ...

# %% [markdown]
# # Splitting the dataset into Training and Testing datasets

# %% [markdown]
# ![draw.drawio.png](data:image/png;base64,...)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.2)

# %% [markdown]
# # Available packages in Colab

# %%
pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.9.1
# aiosignal                        1.3.1
# alabaster                        0.7.13
# albumentations                   1.3.1
# altair                           4.2.2
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.5.0
# arviz                            0.15.1
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.0
# attrs                            23.1.0
# audioread                        3.0.1
# autograd                         1.6.2
# Babel                            2.14.0
# backcall                         0.2.0
# ...

# %% [markdown]
# # Importing dependencies

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout

# %% [markdown]
# # Building the model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model = Sequential()

# First hidden layer
# Normally, for hidden layers, we use the relu activation function.
# In relu activation function, the minaze values will be assigned into 0.
model.add (Dense (units = 10, activation = 'relu', input_dim = len(x_train.columns)))

# Second hidden layer
model.add (Dense (units = 5, activation = 'relu'))

# Output layer
# In sigmoid activation function, we get a probabilistic value as the output.
model.add (Dense (units = 1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 10)                350
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dense_2 (Dense)             (None, 1)                 6
#
# ...
# Total params: 411 (1.61 KB)
# Trainable params: 411 (1.61 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Compiling the model

# %%
# Based on the loss, we can learn that whether the model is training poperly or not.
# In here, it is binary_crossentropy because, this is a binary classification.
model.compile (loss = 'binary_crossentropy', optimizer = 'sgd', metrics = 'accuracy')

# %%
model.fit (x_train, y_train, validation_data = (x_test, y_test), epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 21ms/step - loss: 0.9425 - accuracy: 0.3964 - val_loss: 0.9178 - val_accuracy: 0.2958
# Epoch 2/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.7719 - accuracy: 0.4143 - val_loss: 0.7756 - val_accuracy: 0.3099
# Epoch 3/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6906 - accuracy: 0.4500 - val_loss: 0.7061 - val_accuracy: 0.3521
# Epoch 4/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6535 - accuracy: 0.4536 - val_loss: 0.6728 - val_accuracy: 0.4225
# Epoch 5/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6315 - accuracy: 0.4893 - val_loss: 0.6494 - val_accuracy: 0.5493
# Epoch 6/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.6154 - accuracy: 0.5679 - val_loss: 0.6318 - val_accuracy: 0.7606
# Epoch 7/100
# ...

# %%
model.save ('weights.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
